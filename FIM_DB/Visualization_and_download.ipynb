# %%
#Import necessary libraries
import os
from pathlib import Path

# %%
#Importing required functions
from utils import *
from fim_db import *

# %% [markdown]
# **Vizualize all available benchmark data interactively**
# The .html file will be generated on running this cell and stored in the folder where this code is available.

# %%
#Generation of the html file for visualization
VizualizeFIMavailAOIs(boundary_dir=None, output_html="FIM_AOIs_Visualization.html")
# Out:
# Map saved to FIM_AOIs_Visualization.html
# 'FIM_AOIs_Visualization.html'
